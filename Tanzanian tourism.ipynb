# %%
## import our libraries

import pandas as pd
import numpy as np

# %%
### Read our data

df = pd.read_csv("Historical data of Tanzania Tourism.csv")

df
# Out:
#              ID                   country age_group        travel_with  \
# 0        tour_0                SWIZERLAND     45-64  Friends/Relatives
# 1       tour_10            UNITED KINGDOM     25-44                NaN
# 2     tour_1000            UNITED KINGDOM     25-44              Alone
# 3     tour_1002            UNITED KINGDOM     25-44             Spouse
# 4     tour_1004                     CHINA      1-24                NaN
# ...         ...                       ...       ...                ...
# 4804   tour_993                       UAE     45-64              Alone
# 4805   tour_994  UNITED STATES OF AMERICA     25-44             Spouse
# 4806   tour_995               NETHERLANDS      1-24                NaN
# 4807   tour_997              SOUTH AFRICA     25-44  Friends/Relatives
# 4808   tour_999            UNITED KINGDOM     25-44             Spouse
#
#       total_female  total_male                         purpose  \
# ...

# %%
## Check the shape of your data

df.shape
# Out:
# (4809, 23)

# %%
### View the top 5 rows

df.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_transport_tz  \
# ...

# %%
### The last 5 rows

df.tail()
# Out:
#             ID                   country age_group        travel_with  \
# 4804  tour_993                       UAE     45-64              Alone
# 4805  tour_994  UNITED STATES OF AMERICA     25-44             Spouse
# 4806  tour_995               NETHERLANDS      1-24                NaN
# 4807  tour_997              SOUTH AFRICA     25-44  Friends/Relatives
# 4808  tour_999            UNITED KINGDOM     25-44             Spouse
#
#       total_female  total_male               purpose     main_activity  \
# 4804           0.0         1.0              Business   Hunting tourism
# 4805           1.0         1.0  Leisure and Holidays  Wildlife tourism
# 4806           1.0         0.0  Leisure and Holidays  Wildlife tourism
# 4807           1.0         1.0              Business     Beach tourism
# 4808           1.0         1.0  Leisure and Holidays  Wildlife tourism
#
#                        info_source tour_arrangement  ... package_transport_tz  \
# ...

# %%
### datatype of every features and non missing values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4806 non-null   float64
#  5   total_male             4804 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
### check for missing value

df.isnull().sum()
# Out:
# ID                          0
# country                     0
# age_group                   0
# travel_with              1114
# total_female                3
# total_male                  5
# purpose                     0
# main_activity               0
# info_source                 0
# tour_arrangement            0
# package_transport_int       0
# package_accomodation        0
# package_food                0
# package_transport_tz        0
# package_sightseeing         0
# package_guided_tour         0
# package_insurance           0
# night_mainland              0
# night_zanzibar              0
# payment_mode                0
# first_trip_tz               0
# most_impressing           313
# total_cost                  0
# dtype: int64

# %%
###The unique value in the specified column

df["travel_with"].unique()
# Out:
# array(['Friends/Relatives', nan, 'Alone', 'Spouse', 'Children',
#        'Spouse and Children'], dtype=object)

# %%
MOV = df["travel_with"].mode()[0]
MOV
# Out:
# 'Alone'

# %%
df["travel_with"] = df["travel_with"].fillna(MOV)

# %%
df.isnull().sum()
# Out:
# ID                         0
# country                    0
# age_group                  0
# travel_with                0
# total_female               3
# total_male                 5
# purpose                    0
# main_activity              0
# info_source                0
# tour_arrangement           0
# package_transport_int      0
# package_accomodation       0
# package_food               0
# package_transport_tz       0
# package_sightseeing        0
# package_guided_tour        0
# package_insurance          0
# night_mainland             0
# night_zanzibar             0
# payment_mode               0
# first_trip_tz              0
# most_impressing          313
# total_cost                 0
# dtype: int64

# %%
df["total_female"] = df["total_female"].fillna(df["total_female"].mean())

# %%
df.isnull().sum()
# Out:
# ID                         0
# country                    0
# age_group                  0
# travel_with                0
# total_female               0
# total_male                 5
# purpose                    0
# main_activity              0
# info_source                0
# tour_arrangement           0
# package_transport_int      0
# package_accomodation       0
# package_food               0
# package_transport_tz       0
# package_sightseeing        0
# package_guided_tour        0
# package_insurance          0
# night_mainland             0
# night_zanzibar             0
# payment_mode               0
# first_trip_tz              0
# most_impressing          313
# total_cost                 0
# dtype: int64

# %%
df["total_male"] = df["total_male"].fillna(df["total_male"].mean())

# %%
df.isnull().sum()
# Out:
# ID                         0
# country                    0
# age_group                  0
# travel_with                0
# total_female               0
# total_male                 0
# purpose                    0
# main_activity              0
# info_source                0
# tour_arrangement           0
# package_transport_int      0
# package_accomodation       0
# package_food               0
# package_transport_tz       0
# package_sightseeing        0
# package_guided_tour        0
# package_insurance          0
# night_mainland             0
# night_zanzibar             0
# payment_mode               0
# first_trip_tz              0
# most_impressing          313
# total_cost                 0
# dtype: int64

# %%
df["most_impressing"].dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            4809 non-null   object
#  4   total_female           4809 non-null   float64
#  5   total_male             4809 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
df["most_impressing"] = df["most_impressing"].fillna(df["most_impressing"].mode()[0])

# %%
df.isnull().sum()
# Out:
# ID                       0
# country                  0
# age_group                0
# travel_with              0
# total_female             0
# total_male               0
# purpose                  0
# main_activity            0
# info_source              0
# tour_arrangement         0
# package_transport_int    0
# package_accomodation     0
# package_food             0
# package_transport_tz     0
# package_sightseeing      0
# package_guided_tour      0
# package_insurance        0
# night_mainland           0
# night_zanzibar           0
# payment_mode             0
# first_trip_tz            0
# most_impressing          0
# total_cost               0
# dtype: int64

# %%
### To check for duplicates values

df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4804    False
# 4805    False
# 4806    False
# 4807    False
# 4808    False
# Length: 4809, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
### Drop irrelevant columns

dff = df.drop(columns = ["info_source","tour_arrangement","package_transport_int","package_accomodation","package_food","package_transport_tz",
                       "package_sightseeing","package_guided_tour","package_insurance"])

# %%
dff
# Out:
#              ID                   country age_group        travel_with  \
# 0        tour_0                SWIZERLAND     45-64  Friends/Relatives
# 1       tour_10            UNITED KINGDOM     25-44              Alone
# 2     tour_1000            UNITED KINGDOM     25-44              Alone
# 3     tour_1002            UNITED KINGDOM     25-44             Spouse
# 4     tour_1004                     CHINA      1-24              Alone
# ...         ...                       ...       ...                ...
# 4804   tour_993                       UAE     45-64              Alone
# 4805   tour_994  UNITED STATES OF AMERICA     25-44             Spouse
# 4806   tour_995               NETHERLANDS      1-24              Alone
# 4807   tour_997              SOUTH AFRICA     25-44  Friends/Relatives
# 4808   tour_999            UNITED KINGDOM     25-44             Spouse
#
#       total_female  total_male                         purpose  \
# ...

# %%
### descriptive stat

dff.describe()
# Out:
#        total_female   total_male  night_mainland  night_zanzibar    total_cost
# count   4809.000000  4809.000000     4809.000000     4809.000000  4.809000e+03
# mean       0.926758     1.009575        8.488043        2.304429  8.114389e+06
# std        1.287840     1.138273       10.427624        4.227080  1.222490e+07
# min        0.000000     0.000000        0.000000        0.000000  4.900000e+04
# 25%        0.000000     1.000000        3.000000        0.000000  8.121750e+05
# 50%        1.000000     1.000000        6.000000        0.000000  3.397875e+06
# 75%        1.000000     1.000000       11.000000        4.000000  9.945000e+06
# max       49.000000    44.000000      145.000000       61.000000  9.953288e+07

# %%
## descriptive stat for categorical data

dff.describe(include = object)
# Out:
#             ID                   country age_group travel_with  \
# count     4809                      4809      4809        4809
# unique    4809                       105         4           5
# top     tour_0  UNITED STATES OF AMERICA     25-44       Alone
# freq         1                       695      2487        2379
#
#                      purpose     main_activity payment_mode first_trip_tz  \
# count                   4809              4809         4809          4809
# unique                     7                 9            4             2
# top     Leisure and Holidays  Wildlife tourism         Cash           Yes
# freq                    2840              2259         4172          3243
#
#         most_impressing
# count              4809
# unique                7
# top     Friendly People
# freq               1854

# %%
### frequ

ds= df.groupby("country")["ID"].count()
ds
# Out:
# country
# ALGERIA                       2
# ANGOLA                        1
# ARGENTINA                     1
# AUSTRALIA                   186
# AUSTRIA                      18
#                            ...
# UNITED STATES OF AMERICA    695
# URUGUAY                       1
# YEMEN                         2
# ZAMBIA                      191
# ZIMBABWE                    274
# Name: ID, Length: 105, dtype: int64

# %%
ds.nlargest(n = 3)
# Out:
# country
# UNITED STATES OF AMERICA    695
# UNITED KINGDOM              533
# ITALY                       393
# Name: ID, dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# UNITED STATES OF AMERICA    695
# UNITED KINGDOM              533
# ITALY                       393
# FRANCE                      280
# ZIMBABWE                    274
#                            ...
# NIGER                         1
# MYANMAR                       1
# DOMINICA                      1
# TUNISIA                       1
# ESTONIA                       1
# Name: count, Length: 105, dtype: int64
